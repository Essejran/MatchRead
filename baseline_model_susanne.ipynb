# %%
import pandas as pd

# %% [markdown]
# ### Baseline model: our book recommender recommends the books with the highest average ratings & highest rating counts ###

# %%
data = pd.read_csv('data/averageRatingdf.csv')  
data.head()
# Out:
#                                           book_title       book_author  \
# 0   A Light in the Storm: The Civil War Diary of ...       Karen Hesse
# 1                              Always Have Popsicles    Rebecca Harvin
# 2               Apple Magic (The Collector's series)  Martina Boudreau
# 3   Ask Lily (Young Women of Faith: Lily Series, ...      Nancy N. Rue
# 4   Beyond IBM: Leadership Marketing and Finance ...        Lou Mobley
#
#          isbn  rating_count  average_rating  \
# 0  0590567330             4             2.2
# 1  0964147726             1             0.0
# 2  0942320093             1             0.0
# 3  0310232546             1             8.0
# 4  0962295701             1             0.0
#
#                                           mod_titles
# 0   a light in the storm the civil war diary of a...
# 1                              always have popsicles
# 2                apple magic the collector s series
# 3   ask lily young women of faith lily series boo...
# 4   beyond ibm leadership marketing and finance f...

# %%
# sort highest average ratings

high_ratings = data.sort_values(by='average_rating', ascending=False).head(10)
high_ratings
# Out:
#                                                book_title  \
# 241906                    The day after judgment: A novel
# 240798  The World Out There: Becoming Part of the Lesb...
# 58620                    Discovering French Blanc Level 2
# 170023  Rules for Roommates: The Ultimate Guide to Rec...
# 58626   Discovering Great Music: A New Listener's Guid...
# 240877    The World of Tiers: Volume One (World of Tiers)
# 58628                          Discovering H.P. Lovecraft
# 240883  The World of Wizards : Modern Magical Tools an...
# 240885  The World of Zines: A Guide to the Independent...
# 170018                       Rules for Civilized Behavior
#
#                    book_author        isbn  rating_count  average_rating  \
# 241906             James Blish  0571094503             1            10.0
# 240798     Michael Thomas Ford  1565842340             1            10.0
# 58620                  Valette  0395866642             1            10.0
# 170023      Mary Lou Podlasiak  0595129838             1            10.0
# 58626              Roy Hemming  1557040273             1            10.0
# 240877      Philip Jose Farmer  0312857616             1            10.0
# 58628       Darrell Schweitzer  1587154714             1            10.0
# 240883             Anton Adams  1586637568             1            10.0
# 240885          Mike Gunderloy  014016720X             1            10.0
# 170018  Sydney Morgan D'Angelo  0595218466             1            10.0
#
#                                                mod_titles
# 241906                     the day after judgment a novel
# 240798  the world out there becoming part of the lesbi...
# 58620                    discovering french blanc level 2
# 170023  rules for roommates the ultimate guide to recl...
# 58626   discovering great music a new listener s guide...
# 240877      the world of tiers volume one world of tiers
# 58628                           discovering h p lovecraft
# 240883  the world of wizards modern magical tools and ...
# 240885  the world of zines a guide to the independent ...
# 170018                       rules for civilized behavior

# %%
#sort high rating count

high_count = data.sort_values(by='rating_count', ascending=False).head(10)
high_count
# Out:
#                                                book_title     book_author  \
# 263401                                        Wild Animus    Rich Shapero
# 220079                          The Lovely Bones: A Novel    Alice Sebold
# 205459                                  The Da Vinci Code       Dan Brown
# 59121     Divine Secrets of the Ya-Ya Sisterhood: A Novel   Rebecca Wells
# 229201                The Red Tent (Bestselling Backlist)   Anita Diamant
# 5790                                      A Painted House    John Grisham
# 231647                            The Secret Life of Bees   Sue Monk Kidd
# 181982                             Snow Falling on Cedars  David Guterson
# 15988                                 Angels &amp; Demons       Dan Brown
# 261664  Where the Heart Is (Oprah's Book Club (Paperba...    Billie Letts
#
#               isbn  rating_count  average_rating  \
# 263401  0971880107          2502             1.0
# 220079  0316666343          1295             4.5
# 205459  0385504209           883             4.7
# 59121   0060928336           732             3.4
# 229201  0312195516           723             4.3
# 5790    044023722X           647             3.2
# 231647  0142001740           615             4.2
# 181982  067976402X           614             3.3
# 15988   0671027360           586             3.7
# 261664  0446672211           585             4.1
#
#                                              mod_titles
# 263401                                      wild animus
# 220079                         the lovely bones a novel
# 205459                                the da vinci code
# 59121    divine secrets of the ya ya sisterhood a novel
# 229201               the red tent bestselling backlist
# 5790                                    a painted house
# 231647                          the secret life of bees
# 181982                           snow falling on cedars
# 15988                                 angels amp demons
# 261664  where the heart is oprah s book club paperback

# %%
recommendations = data.sort_values(by=['average_rating', 'rating_count'], ascending=[False, False])
top_10_recs = recommendations.head(10)
top_10_recs
# Out:
#                                                book_title  \
# 219755  The Lord of the Rings (Leatherette Collector's...
# 25168                    Betsy and Joe (Betsy &amp; Tacy)
# 37660           Charlottes Web Special Read Along Edition
# 38750                           Chimps Don't Wear Glasses
# 39739                                         Cinder Edna
# 58339       Dinotopia: A Land Apart from Time (Dinotopia)
# 99319   I Spy Treasure Hunt: A Book of Picture Riddles...
# 196534        The Annotated Alice: The Definitive Edition
# 32167                            Bug, Witch and the Robot
# 44227   Cooking with Mickey &amp; Friends : More Than ...
#
#                  book_author        isbn  rating_count  average_rating  \
# 219755      J. R. R. Tolkien  0395193958             6            10.0
# 25168     Maud Hart Lovelace  006440546X             4            10.0
# 37660              E B White  0760707251             4            10.0
# 38750   Laura Numeroff Joffe  0689801505             4            10.0
# 39739          Ellen Jackson  0688123228             4            10.0
# 58339           James Gurney  0060280034             4            10.0
# 99319            Walter Wick  0439042445             4            10.0
# 196534         Lewis Carroll  0393048470             4            10.0
# 32167            Pete Abrams  1929462379             3            10.0
# 44227         Patricia Baird  0786831901             3            10.0
#
#                                                mod_titles
# 219755  the lord of the rings leatherette collector s ...
# 25168                       betsy and joe betsy amp tacy
# 37660           charlottes web special read along edition
# 38750                           chimps don t wear glasses
# 39739                                         cinder edna
# 58339         dinotopia a land apart from time dinotopia
# 99319   i spy treasure hunt a book of picture riddles ...
# 196534         the annotated alice the definitive edition
# 32167                             bug witch and the robot
# 44227   cooking with mickey amp friends more than 30 r...
