# %%
# %run import_data
# Out:
# Continuing with existing version of data folder
# Goodreads dataset loaded successfully as books_goodreads
# Pandas dataframes (books_goodreads, books_big, book, users, ratings) loaded successfully
# Columns in DataFrames 'users' and 'ratings' renamed
# You can use the DataFrames 'books' or 'books_big' - they are exactly the same (big) dataset
# Ready to go!

# %%
# %pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 31.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=69e1bdbfc3f20980bdd5c146d317ea80eb86526b3efc5f7a2724a16699e16246
#   Stored in directory: /Users/laylanyrabia/Library/Caches/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langdetect import detect

# Function to detect language
def detect_language(text):
    try:
        return detect(text)
    except:
        return 'unknown'

# Apply the function to the column and create a new column
books['language'] = books['book_title'].apply(detect_language)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226493 entries, 0 to 226492
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 226493 non-null  object
#  1   book_title           226493 non-null  object
#  2   book_author          226322 non-null  object
#  3   year_of_publication  226493 non-null  int64
#  4   publisher            226493 non-null  object
#  5   image_url_s          226493 non-null  object
#  6   image_url_m          226493 non-null  object
#  7   image_url_l          226493 non-null  object
#  8   genre                195719 non-null  object
#  9   language             226493 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 17.3+ MB

# %%
books.language.unique()
# Out:
# array(['nl', 'en', 'no', 'de', 'cy', 'af', 'tl', 'da', 'pt', 'fr', 'it',
#        'ro', 'sl', 'tr', 'sq', 'id', 'es', 'fi', 'hu', 'et', 'ca', 'so',
#        'pl', 'sv', 'cs', 'sw', 'hr', 'lt', 'vi', 'sk', 'lv', 'unknown'],
#       dtype=object)

# %%
books.language.describe()
# Out:
# count     226493
# unique        32
# top           en
# freq      172904
# Name: language, dtype: object

# %%
books.language.value_counts()
# Out:
# language
# en         172904
# de          16948
# fr           5322
# es           4260
# nl           2891
# it           2467
# af           2377
# tl           2111
# ca           2027
# no           1749
# id           1593
# da           1509
# pt           1477
# ro           1220
# cy            904
# so            889
# sv            853
# et            800
# fi            597
# sw            568
# vi            531
# tr            496
# pl            487
# lt            315
# sl            285
# hr            242
# hu            236
# sq            129
# sk            108
# cs             79
# lv             70
# unknown        49
# Name: count, dtype: int64

# %%
books[books['language'] == 'ca']
# Out:
#              isbn                                         book_title  \
# 291     345470583                                   Xxxholic, Vol. 1
# 339     843108371                                Diva Girl: Mad Libs
# 364      60086637                                      Barracuda 945
# 571     345447581                                Marque and Reprisal
# 608     812967798  Lucia Lucia : A Novel (Ballantine Reader's Cir...
# ...           ...                                                ...
# 225419  590438808                                     Aesop's Fables
# 225520  140441212                   Bhagavad Gita (Penguin Classics)
# 225618  486204227                           Essential German Grammar
# 226194  688212646                                      Ellen Tebbits
# 226244  553213601               Cyrano De Bergerac (Bantam Classics)
#
#              book_author  year_of_publication           publisher  \
# 291                CLAMP                 2004             Del Rey
# ...

# %%
books[books['isbn'] == '671735330']
# Out:
#              isbn                                         book_title  \
# 157351  671735330  BASEBALL HALL OF SHAME: YOUNG FAN'S EDITION 2 ...
#
#        book_author  year_of_publication                      publisher  \
# 157351  Bruce Nash                 1991  Simon Spotlight Entertainment
#
#                                               image_url_s  \
# 157351  http://images.amazon.com/images/P/0671735330.0...
#
#                                               image_url_m  \
# 157351  http://images.amazon.com/images/P/0671735330.0...
#
#                                               image_url_l  \
# 157351  http://images.amazon.com/images/P/0671735330.0...
#
#                                                     genre language
# 157351  Anecdotes, Baseball, Humor, United States, Juv...       de
