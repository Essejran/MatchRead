# %%
# %run import_data.ipynb
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.google.com:443
# Dataset books.csv loaded successfully
# isbn column dropped, isbn13 column kept
# Language codes eng, en-US, en-GB, en-CA unified to 'en'
# Missing publication dates filled in
# 2nd (large) dataset is being downloaded...
# DEBUG:urllib3.connectionpool:https://drive.google.com:443 "GET /uc?export=download&id=1JTY2O32QSn4L3UCB-BxeL0qY-5D1DCIz HTTP/11" 303 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.usercontent.google.com:443
# DEBUG:urllib3.connectionpool:https://drive.usercontent.google.com:443 "GET /download?id=1JTY2O32QSn4L3UCB-BxeL0qY-5D1DCIz&export=download HTTP/11" 200 73293635
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.google.com:443
# Dataset downloaded and saved as data/books2.csv
# DEBUG:urllib3.connectionpool:https://drive.google.com:443 "GET /uc?export=download&id=1i9xdUCFn052HqrFQXSYHEAo0_9vcZjgU HTTP/11" 303 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.usercontent.google.com:443
# DEBUG:urllib3.connectionpool:https://drive.usercontent.google.com:443 "GET /download?id=1i9xdUCFn052HqrFQXSYHEAo0_9vcZjgU&export=download HTTP/11" 200 11017438
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.google.com:443
# Dataset downloaded and saved as data/users.csv
# DEBUG:urllib3.connectionpool:https://drive.google.com:443 "GET /uc?export=download&id=11ckhvFWy_n4br-_UEZW3Aci3cgClYRqD HTTP/11" 303 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): drive.usercontent.google.com:443
# DEBUG:urllib3.connectionpool:https://drive.usercontent.google.com:443 "GET /download?id=11ckhvFWy_n4br-_UEZW3Aci3cgClYRqD&export=download HTTP/11" 200 22633892
# Dataset downloaded and saved as data/ratings.csv
# Pandas dataframes (books_df, books_big, users, ratings) loaded successfully
# Columns renamed and dates converted to dtype: datetime
# Ready to go!

# %%
# import requests
# import pandas as pd

# def get_book_annotation(isbn13):
#     # Define the API endpoint
#     url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn13}'
    
#     # Make the API request
#     response = requests.get(url)
    
#     # Check if the request was successful
#     if response.status_code == 200:
#         data = response.json()
        
#         # Check if any books were found
#         if 'items' in data:
#             # Extract the description from the first item
#             annotation = data['items'][0]['volumeInfo'].get('description', 'No annotation found')
#             return annotation
#         else:
#             return 'No annotation found'
#     else:
#         return 'Error fetching annotation'

# Example usage:
# print(get_book_annotation('9780140449136'))  # Replace with an actual ISBN13

# %%
smol_df = books_big.sample(100)
smol_df.head()
# Out:
#               isbn                                         book_title  \
# 185609  0373107900                                 Cape Of Misfortune
# 232664  0156005123                                     The Immigrants
# 16392   0441138764                        Daughter of the Bright Moon
# 29172   0679751149  Dancing After Hours: Stories (Vintage Contempo...
# 233672  0385473532  The Keys to the Kingdom: The Fs-X Deal and the...
#
#            book_author year_of_publication              publisher  \
# 185609  Yvonne Whittal          1985-01-01              Harlequin
# 232664     Howard Fast          2004-01-01               Harcourt
# 16392       Lynn Abbey          1980-01-01              Ace Books
# 29172      Andre Dubus          1997-01-01      Vintage Books USA
# 233672      Jeff Shear          1994-01-01  Bantam Dell Pub Group
#
#                                               image_url_s  \
# 185609  http://images.amazon.com/images/P/0373107900.0...
# 232664  http://images.amazon.com/images/P/0156005123.0...
# 16392   http://images.amazon.com/images/P/0441138764.0...
# 29172   http://images.amazon.com/images/P/0679751149.0...
# 233672  http://images.amazon.com/images/P/0385473532.0...
#
#                                               image_url_m  \
# 185609  http://images.amazon.com/images/P/0373107900.0...
# 232664  http://images.amazon.com/images/P/0156005123.0...
# 16392   http://images.amazon.com/images/P/0441138764.0...
# 29172   http://images.amazon.com/images/P/0679751149.0...
# 233672  http://images.amazon.com/images/P/0385473532.0...
#
#                                               image_url_l
# 185609  http://images.amazon.com/images/P/0373107900.0...
# 232664  http://images.amazon.com/images/P/0156005123.0...
# 16392   http://images.amazon.com/images/P/0441138764.0...
# 29172   http://images.amazon.com/images/P/0679751149.0...
# 233672  http://images.amazon.com/images/P/0385473532.0...

# %%
# fetch annotations for each book and create a new column
# handle API rate limits by adding a delay between requests
# import time

# def get_book_annotation(isbn13):
#     url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn13}'
#     response = requests.get(url)
    
#     # Respect the rate limit
#     time.sleep(1)
    
#     if response.status_code == 200:
#         data = response.json()
#         if 'items' in data:
#             annotation = data['items'][0]['volumeInfo'].get('description', 'No annotation found')
#             return annotation
#         else:
#             return 'No annotation found'
#     else:
#         return 'Error fetching annotation'

# smol_df['annotation'] = smol_df['isbn13'].apply(get_book_annotation)

# %%
smol_df.head(10)
# Out:
#               isbn                                         book_title  \
# 78623   0671508067            John Hedgecoe's Photographer's Workbook
# 25053   0590312642                     Star Streak : Stories of Space
# 59141   0140052216                                   Leaving Cheyenne
# 28662   0694522597                                        Young Wives
# 27218   0316037451                         The Cat and the Curmudgeon
# 192562  0439296382  What a Girl Wants: The Ultimate Survival Guide...
# 244253  0446356395                                    Triple Jeopardy
# 174646  0720719933                                      Art Detective
# 113723  0138072485              The Sewing Machine As a Creative Tool
# 216221  0140140670                   Granta 46: Crime (Granta, No 46)
#
#              book_author year_of_publication                publisher  \
# 78623      John Hedgecoe          1985-01-01        Granite Impex Ltd
# 25053               Owen          1986-01-01  Scholastic Incorporated
# 59141     Larry McMurtry          1979-01-01            Penguin Books
# 28662   Olivia Goldsmith          2000-01-01              HarperAudio
# 27218    Cleveland Amory          1991-01-01            Little, Brown
# 192562      Karen Cooper          2001-01-01            Chicken House
# 244253   Richard Speight          1989-01-01             Warner Books
# 174646       Hugh Scully          1993-01-01                   Pelham
# 113723       Karen Bakke          1975-01-01            Prentice Hall
# 216221       Bill Buford          1994-01-01            Penguin Books
#
#                                               image_url_s  \
# 78623   http://images.amazon.com/images/P/0671508067.0...
# 25053   http://images.amazon.com/images/P/0590312642.0...
# 59141   http://images.amazon.com/images/P/0140052216.0...
# 28662   http://images.amazon.com/images/P/0694522597.0...
# 27218   http://images.amazon.com/images/P/0316037451.0...
# 192562  http://images.amazon.com/images/P/0439296382.0...
# 244253  http://images.amazon.com/images/P/0446356395.0...
# 174646  http://images.amazon.com/images/P/0720719933.0...
# 113723  http://images.amazon.com/images/P/0138072485.0...
# 216221  http://images.amazon.com/images/P/0140140670.0...
#
#                                               image_url_m  \
# 78623   http://images.amazon.com/images/P/0671508067.0...
# 25053   http://images.amazon.com/images/P/0590312642.0...
# 59141   http://images.amazon.com/images/P/0140052216.0...
# 28662   http://images.amazon.com/images/P/0694522597.0...
# 27218   http://images.amazon.com/images/P/0316037451.0...
# 192562  http://images.amazon.com/images/P/0439296382.0...
# 244253  http://images.amazon.com/images/P/0446356395.0...
# 174646  http://images.amazon.com/images/P/0720719933.0...
# 113723  http://images.amazon.com/images/P/0138072485.0...
# 216221  http://images.amazon.com/images/P/0140140670.0...
#
#                                               image_url_l publishing_year  \
# 78623   http://images.amazon.com/images/P/0671508067.0...            1985
# 25053   http://images.amazon.com/images/P/0590312642.0...            1979
# 59141   http://images.amazon.com/images/P/0140052216.0...            1979
# 28662   http://images.amazon.com/images/P/0694522597.0...   No date found
# 27218   http://images.amazon.com/images/P/0316037451.0...            1991
# 192562  http://images.amazon.com/images/P/0439296382.0...            2001
# 244253  http://images.amazon.com/images/P/0446356395.0...            1989
# 174646  http://images.amazon.com/images/P/0720719933.0...            1993
# 113723  http://images.amazon.com/images/P/0138072485.0...            1976
# 216221  http://images.amazon.com/images/P/0140140670.0...            1994
#
#                                                annotation  \
# 78623                                 No annotation found
# 25053                                 No annotation found
# 59141   My foot's in the stirrup, My pony won't st Goo...
# 28662                                 No annotation found
# 27218   Despite his hard-knock beginnings, Polar Bear ...
# 192562  Provides advice for preteen and teenage girls ...
# 244253  From the author of Desperate Justice comes a d...
# 174646                                No annotation found
# 113723                                No annotation found
# 216221                       A collection of new writing.
#
#                        genre
# 78623            Photography
# 25053       Juvenile Fiction
# 59141                Fiction
# 28662         No genre found
# 27218     Literary Criticism
# 192562   Juvenile Nonfiction
# 244253               Fiction
# 174646              Antiques
# 113723   Embroidery, Machine
# 216221  Literary Collections

# %%
smol_df.genre.nunique()
# Out:
# 46

# %%
smol_df.annotation.nunique()
# Out:
# 81

# %%
smol_df.publishing_year.nunique()
# Out:
# 28

# %%
# import aiohttp
# import asyncio
# import pandas as pd
# import nest_asyncio
# from asyncio import Semaphore
# import logging

# # Apply the nest_asyncio to allow nested event loops
# nest_asyncio.apply()

# # Enable logging for debugging
# logging.basicConfig(level=logging.DEBUG)
# logger = logging.getLogger()

# # Set the maximum number of concurrent requests (adjust based on the API rate limit)
# MAX_CONCURRENT_REQUESTS = 5
# semaphore = Semaphore(MAX_CONCURRENT_REQUESTS)

# async def fetch_annotation(session, isbn13):
#     async with semaphore:
#         url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn13}'
#         try:
#             async with session.get(url) as response:
#                 logger.info(f'Fetching ISBN: {isbn13} with status: {response.status}')
#                 if response.status == 429:  # Too many requests
#                     logger.warning(f'Rate limit hit for ISBN: {isbn13}, retrying after 60 seconds')
#                     await asyncio.sleep(60)  # Wait 60 seconds and try again
#                     return await fetch_annotation(session, isbn13)  # Retry
#                 elif response.status == 200:
#                     data = await response.json()
#                     logger.debug(f'Received data for ISBN: {isbn13}: {data}')
#                     # key = f'ISBN:{isbn13}'
#                     if 'items' in data:
#                         annotation = data['items'][0]['volumeInfo'].get('description', 'No annotation found')
#                         return annotation if annotation else 'No annotation found'
#                     else:
#                         return 'No annotation found'
#                 else:
#                     logger.error(f'Error fetching ISBN: {isbn13}, status code: {response.status}')
#                     return 'Error fetching annotation'
#         except Exception as e:
#             logger.error(f'Exception occurred for ISBN: {isbn13}: {e}')
#             return 'Error fetching annotation'

# async def fetch_annotations_for_dataframe(smol_df, rate_limit=5):
#     async with aiohttp.ClientSession() as session:
#         tasks = []
#         for isbn13 in smol_df['isbn']:
#             tasks.append(fetch_annotation(session, isbn13))
#             if len(tasks) % rate_limit == 0:  # After every 'rate_limit' requests
#                 await asyncio.sleep(1)  # Sleep to respect the rate limit
#         annotations = await asyncio.gather(*tasks)
#     smol_df['annotation'] = annotations
#     return smol_df

# async def main():
#     global smol_df
#     # Assuming smol_df is your existing DataFrame with an 'isbn13' column
#     smol_df = await fetch_annotations_for_dataframe(smol_df)
#     print(smol_df.head())  # Display the updated DataFrame with annotations

# # Instead of asyncio.run(main()), we use an event loop directly:
# loop = asyncio.get_event_loop()
# loop.run_until_complete(main())

# %%
# import aiohttp
# import asyncio
# import pandas as pd
# import nest_asyncio
# from asyncio import Semaphore
# import logging

# # Apply the nest_asyncio to allow nested event loops
# nest_asyncio.apply()

# # Enable logging for debugging
# logging.basicConfig(level=logging.DEBUG)
# logger = logging.getLogger()

# # Set the maximum number of concurrent requests (adjust based on the API rate limit)
# MAX_CONCURRENT_REQUESTS = 5
# semaphore = Semaphore(MAX_CONCURRENT_REQUESTS)

# async def fetch_annotation(session, isbn13):
#     async with semaphore:
#         url = f'https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn13}'
#         try:
#             async with session.get(url) as response:
#                 logger.info(f'Fetching ISBN: {isbn13} with status: {response.status}')
#                 if response.status == 429:  # Too many requests
#                     logger.warning(f'Rate limit hit for ISBN: {isbn13}, retrying after 60 seconds')
#                     await asyncio.sleep(60)  # Wait 60 seconds and try again
#                     return await fetch_annotation(session, isbn13)  # Retry
#                 elif response.status == 200:
#                     data = await response.json()
#                     logger.debug(f'Received data for ISBN: {isbn13}: {data}')
#                     # key = f'ISBN:{isbn13}'
#                     if 'items' in data:
#                         annotation = data['items'][0]['volumeInfo'].get('description', 'No annotation found')
#                         return annotation if annotation else 'No annotation found'
#                     else:
#                         return 'No annotation found'
#                 else:
#                     logger.error(f'Error fetching ISBN: {isbn13}, status code: {response.status}')
#                     return 'Error fetching annotation'
#         except Exception as e:
#             logger.error(f'Exception occurred for ISBN: {isbn13}: {e}')
#             return 'Error fetching annotation'

# async def fetch_annotations_for_dataframe(smol_df, rate_limit=5):
#     async with aiohttp.ClientSession() as session:
#         tasks = []
#         for isbn13 in smol_df['isbn13']:
#             tasks.append(fetch_annotation(session, isbn13))
#             if len(tasks) % rate_limit == 0:  # After every 'rate_limit' requests
#                 await asyncio.sleep(1)  # Sleep to respect the rate limit
#         annotations = await asyncio.gather(*tasks)
#     smol_df['annotation'] = annotations
#     return smol_df

# async def main():
#     global smol_df
#     # Assuming smol_df is your existing DataFrame with an 'isbn13' column
#     smol_df = await fetch_annotations_for_dataframe(smol_df)
#     print(smol_df.head())  # Display the updated DataFrame with annotations

# # Instead of asyncio.run(main()), we use an event loop directly:
# loop = asyncio.get_event_loop()
# loop.run_until_complete(main())

# %%
# smol_df.to_csv('books_with_annotations.csv', index=False)
