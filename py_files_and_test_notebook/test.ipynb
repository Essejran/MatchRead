# %% [markdown]
# ## 1. Loading The Data
# This loads the dataframes that are necessary for the models to work.

# %%
from loading_datasets import load_data
# Out:
# To load the dataframes, run this line of code:
# books_ratings, books_users_ratings, raters_15plus = load_data()

# %%
books_ratings, books_users_ratings, raters_15plus = load_data()

# %%
books_ratings.head()
# Out:
#         isbn                                       book_title    book_author  \
# 0  971880107                                      Wild Animus   Rich Shapero
# 1  316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  385504209                                The Da Vinci Code      Dan Brown
# 3   60928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
#
#    year_of_publication      publisher  \
# 0                 2004        Too Far
# 1                 2002  Little, Brown
# 2                 2003      Doubleday
# 3                 1997      Perennial
# 4                 1998    Picador USA
#
#                                                genre  avg_rating  nr_ratings  \
# 0                               ['Fiction', 'Other']    4.390706         581
# 1                               ['Fiction', 'Other']    8.185290         707
# ...

# %%
books_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195390 entries, 0 to 195389
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 195390 non-null  object
#  1   book_title           195390 non-null  object
#  2   book_author          195390 non-null  object
#  3   year_of_publication  195390 non-null  int64
#  4   publisher            195390 non-null  object
#  5   genre                195390 non-null  object
#  6   avg_rating           195390 non-null  float64
#  7   nr_ratings           195390 non-null  int64
#  8   nr_readers           195390 non-null  int64
#  9   annotations          18685 non-null   object
#  10  mod_title            195390 non-null  object
#  11  mod_author           195390 non-null  object
#  12  mod_publisher        195390 non-null  object
#  13  image_url_s          195390 non-null  object
#  14  image_url_m          195390 non-null  object
# ...

# %%
books_users_ratings.head()
# Out:
#         isbn                       book_title      book_author   user_id  \
# 0  590085417                            Heidi    Johanna Spyri  102967.0
# 1  590085417                            Heidi    Johanna Spyri  111702.0
# 2  590085417                            Heidi    Johanna Spyri  135473.0
# 3  68107468X  Edgar Allen Poe Collected Poems  Edgar Allan Poe  204964.0
# 4  68107468X  Edgar Allen Poe Collected Poems  Edgar Allan Poe  267830.0
#
#    individual_rating  avg_rating  nr_ratings  nr_readers  \
# 0                8.0         8.0           2           3
# 1                8.0         8.0           2           3
# 2                0.0         8.0           2           3
# 3                8.0         8.0           2           2
# 4                8.0         8.0           2           2
#
#                                                genre  year_of_publication  \
# 0  ['Juvenile Fiction', 'Fiction', "Children's Li...                 2021
# ...

# %%
books_users_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917916 entries, 0 to 917915
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 917916 non-null  object
#  1   book_title           917916 non-null  object
#  2   book_author          917916 non-null  object
#  3   user_id              917916 non-null  float64
#  4   individual_rating    917916 non-null  float64
#  5   avg_rating           917916 non-null  float64
#  6   nr_ratings           917916 non-null  int64
#  7   nr_readers           917916 non-null  int64
#  8   genre                917916 non-null  object
#  9   year_of_publication  917916 non-null  int64
#  10  publisher            917916 non-null  object
#  11  annotations          438490 non-null  object
#  12  mod_title            917916 non-null  object
#  13  mod_author           917916 non-null  object
#  14  mod_publisher        917916 non-null  object
# ...

# %%
raters_15plus.head()
# Out:
#         isbn                                       book_title    book_author  \
# 0  971880107                                      Wild Animus   Rich Shapero
# 1  316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  385504209                                The Da Vinci Code      Dan Brown
# 3   60928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
#
#    year_of_publication      publisher  \
# 0                 2004        Too Far
# 1                 2002  Little, Brown
# 2                 2003      Doubleday
# 3                 1997      Perennial
# 4                 1998    Picador USA
#
#                                                genre  avg_rating  nr_ratings  \
# 0                               ['Fiction', 'Other']    4.390706         581
# 1                               ['Fiction', 'Other']    8.185290         707
# ...

# %%
raters_15plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3094 entries, 0 to 3093
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   isbn                 3094 non-null   object
#  1   book_title           3094 non-null   object
#  2   book_author          3094 non-null   object
#  3   year_of_publication  3094 non-null   int64
#  4   publisher            3094 non-null   object
#  5   genre                3094 non-null   object
#  6   avg_rating           3094 non-null   float64
#  7   nr_ratings           3094 non-null   int64
#  8   nr_readers           3094 non-null   int64
#  9   annotations          1143 non-null   object
#  10  mod_title            3094 non-null   object
#  11  mod_author           3094 non-null   object
#  12  mod_publisher        3094 non-null   object
#  13  image_url_s          3094 non-null   object
#  14  image_url_m          3094 non-null   object
# ...

# %% [markdown]
# ## 2. Using The Search Engines (Content-Based)
# Always load the data first for this to work.

# %% [markdown]
# #### I. Search Engine For Book Titles

# %%
from search_engines import search_titles

test_query = "Harry Potter"  # Simulate a user input for the search query
search_results = search_titles(test_query, raters_15plus)

print("Search Results:\n", search_results)
# Out:
# Search Results:
#            isbn                                         book_title  \
# 10   59035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 67   43935806X  Harry Potter and the Order of the Phoenix (Boo...
# 58   439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 197  439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 199  439139597       Harry Potter and the Goblet of Fire (Book 4)
# 150  439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 277  439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 288  590353403     Harry Potter and the Sorcerer's Stone (Book 1)
# 206  439139600       Harry Potter and the Goblet of Fire (Book 4)
# 663  43936213X     Harry Potter and the Sorcerer's Stone (Book 1)
#
#        book_author  year_of_publication               publisher  \
# 10   J. K. Rowling                 1999  Arthur A. Levine Books
# 67   J. K. Rowling                 2003              Scholastic
# ...

# %% [markdown]
# #### II. Search Engine For Book Authors

# %%
from search_engines import search_authors

test_query = "James Baldwin"  # Simulate a user input for the search query
search_results = search_authors(test_query, raters_15plus)

print("Search Results:\n", search_results)
# Out:
# Search Results:
#             isbn                                         book_title  \
# 346   316969680                                    The Beach House
# 255   446608815                                Pop Goes the Weasel
# 548   316666009                                1st to Die: A Novel
# 1095  316693294                                      Cat and Mouse
# 850   316693286                                Pop Goes the Weasel
# 1306  345446666   Death in Holy Orders : An Adam Dalgliesh Mystery
# 1021  446613843                                         The Jester
# 1166  446600474                              Season of the Machete
# 2146  345430573  A Certain Justice (Adam Dalgliesh Mysteries (P...
# 2855  375412557  Death in Holy Orders (Adam Dalgliesh Mysteries...
#
#           book_author  year_of_publication                 publisher  \
# 346   James Patterson                 2002             Little, Brown
# 255   James Patterson                 2000             Warner Vision
# ...

# %% [markdown]
# #### III. Search Engine Using Multiple Features

# %%
from search_engines import search_all

test_query = "george orwell 1984 sci-fi"  # Simulate a user input for the search query
search_results = search_all(test_query, raters_15plus)

print("Search Results:\n", search_results)
# Out:
# Search Results:
#             isbn                    book_title       book_author  \
# 209   451524934                          1984     George Orwell
# 302   451526341                   Animal Farm     George Orwell
# 1307  553582364           A Traitor to Memory  Elizabeth George
# 1493  553576089  In the Presence of the Enemy  ELIZABETH GEORGE
# 1844  553284363              Payment in Blood  Elizabeth George
# 2388  451519841                          1984     George Orwell
# 1500  553572512         Playing for the Ashes  ELIZABETH GEORGE
# 1289  553575090         Deception on His Mind  ELIZABETH GEORGE
# 1432  440185327                Thurston House    Danielle Steel
# 2995  553801279           A Traitor to Memory  Elizabeth George
#
#       year_of_publication         publisher  \
# 209                  1990       Signet Book
# 302                  2004            Signet
# 1307                 2002      Bantam Books
# 1493                 1997            Bantam
# ...

# %% [markdown]
# ## 3. Using The Baseline Recommender (Cold-Start Model)

# %%
from baseline_recommender import recommender_baseline

recommendations_bl = recommender_baseline(books_ratings)

print("Recommendations:\n", recommendations_bl, 
      "\nNumber of Recommendations: ", recommendations_bl.isbn.nunique())
# Out:
# Recommendations:
#               isbn                                         book_title  \
# 6375   1888054557   Postmarked Yesteryear: 30 Rare Holiday Postcards
# 15018   394800893                    The Sneetches and Other Stories
# 11188  1571456988  Uncle John's Supremely Satisfying Bathroom Rea...
# 8363    394831292  Oh, the Thinks You Can Think! (I Can Read It A...
# 22150   395282659                                         The Hobbit
# 22151   679821481     Six by Seuss: A Treasury of Dr. Seuss Classics
# 26063   395193958  The Lord of the Rings (Leatherette Collector's...
# 9756    373790651    The Ultimate Seduction (Harlequin Blaze, No 61)
# 11463  1565548353  Halloween: Romantic Art and Customs Of Yestery...
# 12523    44409494                Hollywoodn't: A Queer Postcard Book
#
#                                              image_url_m
# 6375   http://images.amazon.com/images/P/1888054557.0...
# 15018  http://images.amazon.com/images/P/0394800893.0...
# ...

# %% [markdown]
# ## 4. Using The Random Recommender

# %%
from random_recommender import recommender_random

recommendations_random = recommender_random(books_ratings, 10)

print("Recommendations:\n", recommendations_random, "\nNumber of Recommendations: ", recommendations_random.isbn.nunique())
# # Example usage
# random_recommendations = get_random_book_recommendations(all_cleaned, num_recommendations=20)

# # Display the recommendations
# random_recommendations[['mod_book_title', 'mod_book_author', 'book_rating']]
# Out:
# Recommendations:
#                isbn                                         book_title  \
# 43412    812574974                          Man From Mundania (Xanth)
# 46560    312961316                                       Another View
# 21617    590496379                  The Discovery (Animorphs, No. 20)
# 181421   722528515  Overcoming Depression: Practical Steps Toward ...
# 148092   142196304  The Desert Pilgrim: En Route to Mysticism and ...
# 64104   1565890256          Secrets of Happiness (Secrets Gift Books)
# 143908   842346643                        Mystery of God's Providence
# 145516   93502879X  Basta! Land and the Zapatista Rebellion in Chi...
# 41471    806913681  Spirit Medicine: Native American Teachings to ...
# 88056    821741942                                        Witch Spell
#
#                  book_author  year_of_publication                   publisher  \
# 43412          Piers Anthony                 2000                 Tor Fantasy
# ...

# %% [markdown]
# ## 5. Using The Collaborative Filtering Recommender

# %%
from collab_filtering_recommender import recommender_cf

liked_books = ['006440546X', '1929462379', '1853263451', 
               '1891575139', '9505811322', '1561840718']
recommendations_cf = recommender_cf(liked_books, books_users_ratings)

print("Recommendations:\n", recommendations_cf, "\nNumber of Recommendations: ", recommendations_cf.isbn.nunique())
# Out:
# Recommendations:
#           isbn                                         book_title  \
# 0  1903436346  The Winter's Tale - Arden Shakespeare : Third ...
# 1   552136328               Toady: Welcome to the Horror Club...
# 2   140071202  A Christmas Carol in Prose Being a Ghost Story...
# 3   933635672                 Cthulhu Casebook (Call of Cthulhu)
# 4   919645038                                    Iroquois Crafts
# 5   870541595  Tales of the Cthulhu Mythos: Golden Anniversar...
# 6   719536324                     John Betjeman: Collected Poems
# 7   751510041                                             Relics
# 8   441435351   Kent Montana and the Really Ugly Thing from Mars
# 9   340541946        Herbcraft: The Cultivation and Use of Herbs
#
#                                          image_url_m
# 0  http://images.amazon.com/images/P/1903436346.0...
# 1  http://images.amazon.com/images/P/0552136328.0...
# 2  http://images.amazon.com/images/P/0140071202.0...
# ...
