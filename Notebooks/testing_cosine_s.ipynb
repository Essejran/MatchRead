# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# If you don't have the file data/all_cleaned.csv then please uncomment this line:
# %run EDA_Alida.ipynb

# %%
all_cleaned = pd.read_csv('../data/all_cleaned.csv')

# %% [markdown]
# #### Content-based filtering: recommending books based on book titles ####

# %%
all_cleaned
# Out:
#               isbn                                         book_title  \
# 0       068160204X                                         The Royals
# 1       068160204X                                         The Royals
# 2       068160204X                                         The Royals
# 3       068160204X                                         The Royals
# 4       068160204X                                         The Royals
# ...            ...                                                ...
# 183595   684719274                                        Ethan Frome
# 183596  038528120X                                           CATCH 22
# 183597  B0000VZEFK  Is That a Gun in Your Pocket?: Women's Experie...
# 183598  1551103982  The Cycling Adventures of Coconut Head: A Nort...
# 183599  1551103982  The Cycling Adventures of Coconut Head: A Nort...
#
#               book_author  year_of_publication                   publisher  \
# 0            Kitty Kelley                 2020            Bausch & Lombard
# 1            Kitty Kelley                 2020            Bausch & Lombard
# 2            Kitty Kelley                 2020            Bausch & Lombard
# 3            Kitty Kelley                 2020            Bausch & Lombard
# 4            Kitty Kelley                 2020            Bausch & Lombard
# ...                   ...                  ...                         ...
# 183595      Edith Wharton                 1910       Scribner Book Company
# 183596      JOSEPH HELLER                 1904                       Delta
# 183597  Rachel Abramowitz                 1900                Random House
# 183598        Ted Schredd                 1900  Graphic Arts Center Pub Co
# 183599        Ted Schredd                 1900  Graphic Arts Center Pub Co
#
#                                                     genre   user_id  \
# 0                                                 unknown   16634.0
# 1                                                 unknown   87141.0
# 2                                                 unknown  169736.0
# 3                                                 unknown  208406.0
# 4                                                 unknown  230496.0
# ...                                                   ...       ...
# 183595  Accident victims, American fiction (fictional ...  127035.0
# 183596  Open Library Staff Picks, Satire, War stories,...   25700.0
# 183597                                            unknown   56856.0
# 183598  Bicycle touring, Description and travel, Journ...  101606.0
# 183599  Bicycle touring, Description and travel, Journ...  216884.0
#
#         book_rating                             location      age  \
# 0               0.0           little rock, arkansas, usa     42.0
# 1               0.0    huntington beach, california, usa  unknown
# 2               7.0          minneapolis, minnesota, usa     34.0
# 3               0.0           kansas city, missouri, usa     30.0
# 4               0.0         simi valley, california, usa     34.0
# ...             ...                                  ...      ...
# 183595          0.0                     fayetteville, ,      52.0
# 183596         10.0                greenhills, ohio, usa  unknown
# 183597          0.0           escondido, california, usa     23.0
# 183598          7.0       niagara falls, ontario, canada     32.0
# 183599          0.0  coquitlam, british columbia, canada  unknown
#
#         age_numeric age_bins    mod_book_author  \
# 0              42.0    Adult       kitty kelley
# 1               NaN  unknown       kitty kelley
# 2              34.0    Adult       kitty kelley
# 3              30.0    Adult       kitty kelley
# 4              34.0    Adult       kitty kelley
# ...             ...      ...                ...
# 183595         52.0   Mature      edith wharton
# 183596          NaN  unknown      joseph heller
# 183597         23.0    Adult  rachel abramowitz
# 183598         32.0    Adult        ted schredd
# 183599          NaN  unknown        ted schredd
#
#                                            mod_book_title  \
# 0                                              the royals
# 1                                              the royals
# 2                                              the royals
# 3                                              the royals
# 4                                              the royals
# ...                                                   ...
# 183595                                        ethan frome
# 183596                                           catch 22
# 183597  is that a gun in your pocket womens experience...
# 183598  the cycling adventures of coconut head a north...
# 183599  the cycling adventures of coconut head a north...
#
#                      mod_publisher country
# 0                   bausch lombard     usa
# 1                   bausch lombard     usa
# 2                   bausch lombard     usa
# 3                   bausch lombard     usa
# 4                   bausch lombard     usa
# ...                            ...     ...
# 183595       scribner book company     NaN
# 183596                       delta     usa
# 183597                random house     usa
# 183598  graphic arts center pub co  canada
# 183599  graphic arts center pub co  canada
#
# [183600 rows x 16 columns]

# %%
# Group by 'isbn' and count the number of ratings for each ISBN
isbn_rating_counts = all_cleaned.groupby(['mod_book_title', 'book_author', 'isbn']).size().reset_index(name='rating_count')

# Display the DataFrame to verify the result
isbn_rating_counts.sort_values('rating_count', ascending=False).head().plot(kind='bar', x='mod_book_title', y='rating_count', color='skyblue')
# Out:
# <Axes: xlabel='mod_book_title'>

# %%
isbn_rating_counts.head()
# Out:
#                                       mod_book_title              book_author  \
# 0                                         0815 heute                    Kirst
# 1                                              1 2 3               Tana Hoban
# 2                          10 000 dreams interpreted  Gustavus Hindman Miller
# 3                                      100 chocolate    Katherine Khodorowsky
# 4  1000 years 1000 people ranking the men and wom...    Agnes Hooper Gottlieb
#
#          isbn  rating_count
# 0  3442013453             1
# 1  068802579X             3
# 2  1862044082             1
# 3  1577173074             1
# 4  1568362536             4

# %%
# including the average rating for each book
# Calculate the average rating for each book

to_be_rated = all_cleaned[['isbn', 'book_rating']]
averageRating = to_be_rated.groupby('isbn')['book_rating'].mean().round(1).reset_index()
averageRating.rename(columns={'book_rating': 'average_rating'}, inplace=True)
average_rating = averageRating[['isbn','average_rating']]

# Merge the average ratings back with the original dataset
averageRatingdf = pd.merge(isbn_rating_counts, average_rating, on='isbn', how='left')

# Remove duplicate entries
#averageRatingdf = averageRatingdf[['isbn', 'average_rating']].drop_duplicates(subset=['isbn'])

averageRatingdf.head()
# Out:
#                                       mod_book_title              book_author  \
# 0                                         0815 heute                    Kirst
# 1                                              1 2 3               Tana Hoban
# 2                          10 000 dreams interpreted  Gustavus Hindman Miller
# 3                                      100 chocolate    Katherine Khodorowsky
# 4  1000 years 1000 people ranking the men and wom...    Agnes Hooper Gottlieb
#
#          isbn  rating_count  average_rating
# 0  3442013453             1             7.0
# 1  068802579X             3             5.3
# 2  1862044082             1             0.0
# 3  1577173074             1             0.0
# 4  1568362536             4             6.8

# %%
sns.boxplot(averageRatingdf.rating_count)
# Out:
# <Axes: ylabel='rating_count'>

# %%
averageRatingdf['mod_book_title'].nunique()
# Out:
# 57107

# %%
# Reducing shape of dataframe

ratings = averageRatingdf[averageRatingdf['rating_count'] >= 15]    #filtering out books with less than 15 ratings
ratings.shape
# Out:
# (1488, 5)

# %%
# turning titles into TD-IDF matrix => Term Frequency-Inverse Document Frequency
from sklearn.feature_extraction.text import TfidfVectorizer

# vectorizer takes a list of strings as input and turns it into a fd-idf matrix
vectorizer = TfidfVectorizer()

tdidf = vectorizer.fit_transform(ratings['mod_book_title'])

# %%
# to do comparison between books, we need to calculate the cosine similarity between the books

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re


# query function:

def search(query, vectorizer):
# setting up a search query

    #query = 'The Hobbit'
# preparing the string in the same way as the mod titles above
    processed = re.sub('[^a-zA-Z0-9]', ' ', query.lower())

# we need to turn the query into a vector using the vectorizer

    query_vector = vectorizer.transform([processed])

# to find the similarities we calculate the cosine similarity between the query vector and the tdidf matrix
    similarity = cosine_similarity(query_vector, tdidf).flatten() # flatten is used to turn the matrix into a 1D array

# to find the indices of the 10 largest similarities

    indices = np.argpartition(similarity, -10)[-10:]

# use indices to index the titles

    results = ratings.iloc[indices]   

# as there are many books with the title "The Hobbit", we only want those with the highest number of ratings

    results = results.sort_values(by='rating_count', ascending=False)

    return results.head(10)

# %%
search('lord of the rings', vectorizer)
# Out:
#                                           mod_book_title  \
# 52872                             the teeth of the tiger
# 48512                             the eyes of the dragon
# 52915                                     the thief lord
# 31237                            lord of the desert mira
# 31245  lord of the vampires the diaries of the family...
# 31222  lord fouls bane the chronicles of thomas coven...
# 31239                                  lord of the flies
# 50051  the legend of bagger vance a novel of golf and...
# 26418  knight of the black rose ravenloft terror of l...
# 16340  el senor de los anillos la comunidad del anill...
#
#                 book_author        isbn  rating_count  average_rating
# 52872            Tom Clancy  039915079X            44             3.8
# 48512          Stephen King  067081458X            31             4.5
# 52915        Cornelia Funke  043942089X            31             2.6
# 31237          Diana Palmer  1551666170            22             1.3
# 31245     Jeanne Kalogridis  044022442X            20             2.3
# 31222  Stephen R. Donaldson  034531011X            18             1.2
# 31239       William Golding  1573226122            18             6.1
# 50051     Steven Pressfield  038072751X            16             2.9
# 26418          James Lowder  1560761563            16             2.2
# 16340      J. R. R. Tolkien  8445071408            16             6.6
