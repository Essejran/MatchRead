# %%
import pandas as pd

# %% [markdown]
# ### Baseline model: our book recommender recommends the books with the highest average ratings & highest rating counts ###

# %%
# %run import_data_
# Out:
# Continuing with existing version of data folder
# Goodreads dataset loaded successfully as books_goodreads
# Pandas dataframes (books_goodreads, books_big, book, users, ratings) loaded successfully
# Columns in DataFrames 'users' and 'ratings' renamed
# You can use the DataFrames 'books' or 'books_big' - they are exactly the same (big) dataset
# loading books_ratings and books_users_ratings
# Ready to go!

# %%
data = books_ratings.copy()  
data.head()
# Out:
#         isbn                                       book_title    book_author  \
# 0  971880107                                      Wild Animus   Rich Shapero
# 1  316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  385504209                                The Da Vinci Code      Dan Brown
# 3   60928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
#
#    year_of_publication      publisher  \
# 0                 2004        Too Far
# 1                 2002  Little, Brown
# 2                 2003      Doubleday
# 3                 1997      Perennial
# 4                 1998    Picador USA
#
#                                                genre  avg_rating  nr_ratings  \
# 0                               ['Fiction', 'Other']    4.390706         581
# 1                               ['Fiction', 'Other']    8.185290         707
# ...

# %%
# sort highest average ratings

high_ratings = data.sort_values(by='avg_rating', ascending=False).head(10)
high_ratings
# Out:
#              isbn                                         book_title  \
# 114862  877736278  WAY OF A PILGRIM-POCKET (Shambhala Pocket Clas...
# 76526   44010694X                                        Born to Run
# 76524   440024463                                     The Endearment
# 76523   439597528                                             Shiloh
# 76522   439568412          One Day at Horrorland (Goosebumps Series)
# 76521   439475198                    A Crazy, Mixed-Up Spanglish Day
# 76520   439443261  Fairies All Year Long: With Shiny Fingernail S...
# 76519   439434866       Harry Potter Paperback Boxed Set (Books 1-4)
# 76518   439420784                 Dream Thief (Secrets of Droon, 17)
# 76517   439386012  The Vile Village (A Series of Unfortunate Even...
#
#                     book_author  year_of_publication                publisher  \
# 114862               OLGA SAVIN                 1991                Shambhala
# ...

# %%
#sort high rating count

high_count = data.sort_values(by='nr_ratings', ascending=False).head(10)
high_count
# Out:
#          isbn                                         book_title  \
# 1   316666343                          The Lovely Bones: A Novel
# 0   971880107                                        Wild Animus
# 2   385504209                                  The Da Vinci Code
# 4   312195516                The Red Tent (Bestselling Backlist)
# 3    60928336    Divine Secrets of the Ya-Ya Sisterhood: A Novel
# 10  59035342X  Harry Potter and the Sorcerer's Stone (Harry P...
# 6   142001740                            The Secret Life of Bees
# 9   446672211  Where the Heart Is (Oprah's Book Club (Paperba...
# 5   44023722X                                    A Painted House
# 14  452282152                          Girl with a Pearl Earring
#
#         book_author  year_of_publication                publisher  \
# 1      Alice Sebold                 2002            Little, Brown
# 0      Rich Shapero                 2004                  Too Far
# ...

# %%
recommendations = data.sort_values(by=['avg_rating', 'nr_ratings'], ascending=[False, False])
top_10_recs = recommendations.head(10)
top_10_recs
# Out:
#              isbn                                         book_title  \
# 6375   1888054557   Postmarked Yesteryear: 30 Rare Holiday Postcards
# 15018   394800893                    The Sneetches and Other Stories
# 11188  1571456988  Uncle John's Supremely Satisfying Bathroom Rea...
# 8363    394831292  Oh, the Thinks You Can Think! (I Can Read It A...
# 22150   395282659                                         The Hobbit
# 22151   679821481     Six by Seuss: A Treasury of Dr. Seuss Classics
# 26063   395193958  The Lord of the Rings (Leatherette Collector's...
# 9756    373790651    The Ultimate Seduction (Harlequin Blaze, No 61)
# 11463  1565548353  Halloween: Romantic Art and Customs Of Yestery...
# 12523    44409494                Hollywoodn't: A Queer Postcard Book
#
#                       book_author  year_of_publication  \
# 6375   Pamela E. Apkarian-Russell                 2001
# 15018                   Dr. Seuss                 1961
# ...
