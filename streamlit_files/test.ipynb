# %%
# import streamlit as st
import pandas as pd
from collab_filtering_recommender import recommender_cf
from loading_datasets import load_data

# %%
# load the data
books_ratings, books_users_ratings, ratings_15plus, streamlit_df = load_data()

# Combine book title and author into a single column
books_users_ratings['title_author'] = books_users_ratings['book_title'] + ' by ' + books_users_ratings['book_author']

# %%
books_users_ratings['user_id'] = books_users_ratings['user_id'].astype(int)
books_users_ratings['user_id'] = books_users_ratings['user_id'].astype(str)

books_users_ratings['individual_rating'] = books_users_ratings['individual_rating'].astype('int32')
books_users_ratings['avg_rating'] = books_users_ratings['avg_rating'].astype('int32')
books_users_ratings['nr_ratings'] = books_users_ratings['nr_ratings'].astype('int32')
books_users_ratings['nr_readers'] = books_users_ratings['nr_readers'].astype('int32')

# %%
streamlit_df = books_users_ratings[(books_users_ratings['nr_ratings'] > 5) & (books_users_ratings['avg_rating'] > 4)]

# %%
streamlit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 416836 entries, 20 to 917858
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   isbn                 416836 non-null  object
#  1   book_title           416836 non-null  object
#  2   book_author          416836 non-null  object
#  3   user_id              416836 non-null  object
#  4   individual_rating    416836 non-null  int32
#  5   avg_rating           416836 non-null  int32
#  6   nr_ratings           416836 non-null  int32
#  7   nr_readers           416836 non-null  int32
#  8   genre                416836 non-null  object
#  9   year_of_publication  416836 non-null  int64
#  10  publisher            416836 non-null  object
#  11  annotations          272076 non-null  object
#  12  mod_title            416836 non-null  object
#  13  mod_author           416836 non-null  object
#  14  mod_publisher        416836 non-null  object
# ...

# %%
streamlit_df.to_csv("../data/streamlit_df.csv", index=False, encoding="utf-8-sig", sep=";")

# %%
goodreads_original = pd.read_csv("../data/goodreads_original.csv", encoding="utf-8", sep=",")
goodreads_detailed = pd.read_csv("../data/goodreads_detailed.csv", encoding="utf-8", sep=",")

# %%
goodreads_original.head(1)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
#
#   publication_date        publisher\t\t\t
# 0        9/16/2006  Scholastic Inc.\t\t\t

# %%
goodreads_detailed.head(1)
# Out:
#    bookid                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
#
#                              authors  average_rating         isbn13 language  \
# 0  ['J.K. Rowling', 'Mary GrandPré']            4.57  9780439785969       en
#
#    num_pages  ratings_count  text_reviews_count  publication_date  \
# 0        652        2095690               27591              2003
#
#          publisher           annotation               genre
# 0  Scholastic Inc.  No annotation found  ['No genre found']

# %%
# Select specific columns to merge from both DataFrames
goodreads_original_subset = goodreads_original[['isbn', 'isbn13']]
goodreads_detailed_subset = goodreads_detailed[['genre', 'isbn13']]

# Merge on the 'key' column
goodreads_st = pd.merge(goodreads_original_subset, goodreads_detailed_subset, on='isbn13', how='inner')

# Drop rows with any missing values
goodreads_st = goodreads_st.dropna()

# %%
goodreads_st = goodreads_st.drop(columns='isbn13')

# %%
goodreads_st.head()
# Out:
#          isbn                 genre
# 0  0439785960    ['No genre found']
# 1  0439358078    ['No genre found']
# 2  0439554896  ['Juvenile Fiction']
# 3  043965548X    ['No genre found']
# 4  0439682584    ['No genre found']

# %%
data = books_users_ratings.copy()

# %%
data.head()
# Out:
#         isbn                       book_title      book_author user_id  \
# 0  590085417                            Heidi    Johanna Spyri  102967
# 1  590085417                            Heidi    Johanna Spyri  111702
# 2  590085417                            Heidi    Johanna Spyri  135473
# 3  68107468X  Edgar Allen Poe Collected Poems  Edgar Allan Poe  204964
# 4  68107468X  Edgar Allen Poe Collected Poems  Edgar Allan Poe  267830
#
#    individual_rating  avg_rating  nr_ratings  nr_readers  \
# 0                  8           8           2           3
# 1                  8           8           2           3
# 2                  0           8           2           3
# 3                  8           8           2           2
# 4                  8           8           2           2
#
#                                                genre  year_of_publication  \
# 0  ['Juvenile Fiction', 'Fiction', "Children's Li...                 2021
# ...

# %%
# Streamlit app
st.title("MatchRead - Hybrid Book Recommender")


# Multiselect widget with combined title and author as options
liked_books = st.multiselect(
    'Liked Books',
    options=books_users_ratings['title_author'].unique()
)

# Display the selected options
st.write("You selected:", liked_books)

if st.button('Get Recommendations'):
    if liked_books:
        # Convert liked books to their ISBNs
        liked_books_isbn = books_users_ratings[books_users_ratings['book_title'].isin(liked_books)]['isbn'].unique()
        recommendations = recommender_cf(liked_books_isbn)
        
        st.write("Recommended Books:")
        for _, row in recommendations.iterrows():
            st.image(row['image_url_m'], width=100)
            st.write(f"**{row['book_title']}**")
    else:
        st.write("Please select at least one book.")

# %%
load_data()[3]
